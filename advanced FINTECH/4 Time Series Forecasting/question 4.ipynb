# %%
pip install cryptocompare
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import quandl
import json
import requests
import pandas as pd 
import numpy as np

# %%
URL = 'https://min-api.cryptocompare.com/data/histoday?fsym=BTC&tsym=USD&limit=70&api_key=2ce5222a6d0867167d59150d7ad6a4b7616bba7a0d1299da87a444e979ddc5ce'

# %%
answer = requests.get(URL)

# %%
data = json.loads(answer.text)

# %%
data
# Out:
# {'Response': 'Success',
#  'Type': 100,
#  'Aggregated': False,
#  'TimeTo': 1651190400,
#  'TimeFrom': 1645142400,
#  'FirstValueInArray': True,
#  'ConversionType': {'type': 'direct', 'conversionSymbol': ''},
#  'Data': [{'time': 1645142400,
#    'high': 40980.65,
#    'low': 39496.7,
#    'open': 40545.09,
#    'volumefrom': 32514.79,
#    'volumeto': 1308787736.51,
#    'close': 39994.66,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1645228800,
#    'high': 40464.62,
#    'low': 39664.71,
#    'open': 39994.66,
#    'volumefrom': 11674.81,
#    'volumeto': 467744109.72,
#    'close': 40107.12,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1645315200,
#    'high': 40142.98,
#    'low': 38019.97,
#    'open': 40107.12,
#    'volumefrom': 23028.66,
#    'volumeto': 890707081.68,
#    'close': 38397.25,
#    'conversionType': 'direct',
#    'conversionSymbol': ''},
#   {'time': 1645401600,
#    'high': 39495.33,
# ...

# %%
df = pd.DataFrame(data['Data'])
df
# Out:
#           time      high       low      open  volumefrom      volumeto  \
# 0   1645142400  40980.65  39496.70  40545.09    32514.79  1.308788e+09
# 1   1645228800  40464.62  39664.71  39994.66    11674.81  4.677441e+08
# 2   1645315200  40142.98  38019.97  40107.12    23028.66  8.907071e+08
# 3   1645401600  39495.33  36862.52  38397.25    47549.32  1.819939e+09
# 4   1645488000  38458.26  36371.68  37037.39    42886.39  1.605539e+09
# ..         ...       ...       ...       ...         ...           ...
# 66  1650844800  40590.80  38234.70  39466.26    38636.23  1.514244e+09
# 67  1650931200  40797.85  37726.59  40437.52    38188.24  1.492484e+09
# 68  1651017600  39465.62  37900.60  38117.39    34510.32  1.341341e+09
# 69  1651104000  40386.50  38892.10  39252.04    29981.12  1.188928e+09
# 70  1651190400  39922.60  39683.31  39749.75      931.75  3.709218e+07
#
#        close conversionType conversionSymbol
# 0   39994.66         direct
# 1   40107.12         direct
# ...

# %%
df['time'] = pd.to_datetime(df['time'],unit='s')
df
# Out:
#          time      high       low      open  volumefrom      volumeto  \
# 0  2022-02-18  40980.65  39496.70  40545.09    32514.79  1.308788e+09
# 1  2022-02-19  40464.62  39664.71  39994.66    11674.81  4.677441e+08
# 2  2022-02-20  40142.98  38019.97  40107.12    23028.66  8.907071e+08
# 3  2022-02-21  39495.33  36862.52  38397.25    47549.32  1.819939e+09
# 4  2022-02-22  38458.26  36371.68  37037.39    42886.39  1.605539e+09
# ..        ...       ...       ...       ...         ...           ...
# 66 2022-04-25  40590.80  38234.70  39466.26    38636.23  1.514244e+09
# 67 2022-04-26  40797.85  37726.59  40437.52    38188.24  1.492484e+09
# 68 2022-04-27  39465.62  37900.60  38117.39    34510.32  1.341341e+09
# 69 2022-04-28  40386.50  38892.10  39252.04    29981.12  1.188928e+09
# 70 2022-04-29  39922.60  39683.31  39749.75      931.75  3.709218e+07
#
#        close conversionType conversionSymbol
# 0   39994.66         direct
# 1   40107.12         direct
# ...

# %%
df=df[['time','close']]
df.columns = ['Date','close']

# %%
df
# Out:
#          Date     close
# 0  2022-02-18  39994.66
# 1  2022-02-19  40107.12
# 2  2022-02-20  38397.25
# 3  2022-02-21  37037.39
# 4  2022-02-22  38267.75
# ..        ...       ...
# 66 2022-04-25  40437.52
# 67 2022-04-26  38117.39
# 68 2022-04-27  39252.04
# 69 2022-04-28  39749.75
# 70 2022-04-29  39907.97
#
# [71 rows x 2 columns]

# %%
##Analysis process: phase I: I selected the price of bitcoin for 70 days since February 18, 2022 to explore and study the factors of the war between Russia and Ukraine and the price changes of bulk commodities caused by them, as well as the price change mechanism of bitcoin caused by the price changes of bulk energy commodities such as energy, oil and natural gas. Phase II: Analysis: however, we can see that the price of bitcoin fluctuates around 37000-38000 within a period of 70 days, and there is no obvious upward or downward trend of price, which shows that the price changes of international crude oil, natural gas and other bulk energy commodities caused by the war between Russia and Ukraine will not directly affect the trading process and price changes of bitcoin.
